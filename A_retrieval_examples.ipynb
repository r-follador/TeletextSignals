# %% [markdown]
# # Retrieval
# Semantic retrieval using vector embeddings and full text search, followed by cross-encoder reranking

# %%
from modules.document_retriever import DocumentRetriever
from modules.notebook_helpers import display_search_results

dr = DocumentRetriever()

def retrieval_query(query):
    rows = dr.search_rerank(query, k=20, top_k=3)
    display_search_results(rows)
# Out:
# /home/rainer/IdeaProjects/TeletextSignals/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
retrieval_query("Wann starb Pele?")
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Grabmal von Fussballer Pelé zugänglich — 2023-05-16
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8382
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 6.1542
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>a50182ef-5837-4aad-b295-bbcd9a354bae
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Knapp fünf Monate nach dem Tod von Pelé ist das Grabmal der brasilianischen Fussball-Legende in der Hafenstadt
# Santos fürs Publikum eröffnet worden.
#
# Zwei goldene Statuen begrüssen die&nbsp; &nbsp;Besuchenden im Mausoleum. Am Boden hat es Kunstrasen und an den Wänden Bilder von jubelndem Fussballpublikum. Auch wichtige Momente der Karriere sind zu sehen. «Das wurde mit viel Liebe von Menschen gemacht, die ihn kannten», sagte Pelés Sohn Edinho.
#
# Fans, die das Grabmal besichtigen&nbsp; &nbsp;wollen, können sich kostenlos auf der Internetseite des Friedhofs «Memorial Necrópole Ecumênica» anmelden. Pelé war am 29. Dezember 2022 im Alter von 82 Jahren an Krebs gestorben.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Pele Krebsleiden erlegen — 2022-12-29
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8864
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 5.8497
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>0c6de64d-6f44-4534-bdce-e2a9860adeac
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Brasiliens Fussball-Legende Pele ist tot. Der Jahrhundertfussballer erlag am Donnerstag im Alter von 82 Jahren einem Krebsleiden. Pele hatte sich seit dem 29. November im Krankenhaus befunden, um die Chemotherapie gegen einen Dickdarmtumor neu einzustellen. Medienberichten zufolge soll die Chemotherapie zuletzt nicht mehr angeschlagen haben.
#
# Die am meisten beachteten Erfolge errang Pelé mit der Nationalmannschaft. 1958, 1962 und 1970 führte er die "Seleção" mit herausragenden Leistungen zu drei WM-Triumphen. Er ist bis heute der einzige Spieler, der dreimal Weltmeister wurde.&nbsp;
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     «König Pele Tag» in Brasilien — 2024-07-03
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8752
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 5.1609
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>72d9be27-b7f8-434b-a504-d5c38f0f4443
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Fussball-Legende Pelé bekommt einen&nbsp; eigenen Gedenktag in Brasilien. Der «König Pele Tag» wird jeweils am
# 19. November gefeiert.
#
# Das Datum hat eine Bedeutung: Am
# 19. November 1969 schiesst Pelé sein tausendstes Tor seiner Karriere. Pelé gilt als einer der grössten Fussballer aller Zeiten. Mit der brasilianischen Nationalmannschaft wird er dreimal Weltmeister.
#
# Als Edson Arantes do Nascimento geboren, stirbt Pelé Ende 2022 mit 82 an den Folgen seines Krebsleidens.
#             </p>
#         </div>

# %%
# Question in different language
retrieval_query("Was there a fire in Chur GR?")
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Wohnungsbrand in Chur ist gelegt worden — 2019-01-13
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8078
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 7.9957
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>c1cc0d57-b441-46c5-9181-362ad99cd1b4
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Der Brand in einem Mehrfamilienhaus in Chur in der Nacht zum Sonntag sei nach ersten Erkenntnissen gelegt worden. Das meldet die Kantonspolizei Graubünden.
#
# Beim Brand kamen drei Personen ums Leben, laut der Polizei zwei Kinder und deren Vater. Im Vordergrund der Ermittlungen stehe ein vom Vater absichtlich verursachter Brand. Es kam zu mindestens einer Explosion, verursacht durch Brandbeschleuniger, wie es in einer Mitteilung der Polizei hiess.
#
#
# Sechs weitere Bewohner des Hauses und zwei Feuerwehrleute seien mit Verdacht auf eine Rauchgasvergiftung ins Spital gebracht worden. Insgesamt habe die Feuerwehr fast 50 Personen aus den 38 Wohnungen evakuiert, so die Polizei.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Mehrere Gebäude in Chur niedergebrannt — 2008-04-17
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8187
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 7.5088
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>17-04-2008_Mehrere_Gebaude_in_Chur_niedergebrannt
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Bei einem Brand in Chur sind zwei Häuser und zwei Ställe niedergebrannt. Verletzt wurde bei dem Unglück niemand, wie die Kantonspolizei Graubünden mitteilte. Bei den betroffenen Gebäuden an der Kasernenstrasse handelte es sich um Abbruchprojekte. Passanten hatten eine starke Rauchentwicklung festgestellt und Alarm geschlagen. Wenig später standen die Gebäude in Vollbrand. Die Stützpunktfeuerwehr Chur, welche mit rund 60 Leuten im Einsatz stand, konnte ein Übergreifen auf weitere Gebäude verhindern. Zur Höhe des Sachschadens und zur Brandursache lagen noch keine Angaben vor.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Felssturz in einem Churer Seitental — 2018-05-07
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.7976
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 7.3398
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>9f87da75-7320-449c-b7c4-56192042a07c
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>In der Nähe von Chur hat sich am Montagnachmittag ein Felssturz ereignet, dessen Ausmass noch nicht bekannt ist.
#
# Die Kantonspolizei Graubünden bestätigte einen Bericht des Onlineportals von «20 Minuten», wonach zuhinterst im Scalära-Tobel an der Grenze zu Trimmis das Rumpeln von stürzenden Steinen zu hören und Staubwolken zu sehen gewesen seien.
#
# Das Gebiet sei, abgesehen von etwaigen Ferienhäusern, mutmasslich unbewohnt, teilte die Polizei mit. Es werde nun abgeklärt, ob jemand zu Schaden gekommen sei.
#             </p>
#         </div>

# %%
retrieval_query("Hat der ZSC gegen Davos gewonnen?")
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     ZSC Lions siegen in Davos — 2005-03-28
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e6f2ff;color:#003366;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     FTS: 0.0063
#                 </span>
#
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8809
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 10.9140
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>28-03-2005_EISHOCKEY_ZSC_Lions_siegen_in_Davos
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Die ZSC Lions haben die erste Partie im Playoff-Final gegen den HC Davos mit 6:4 gewonnen und damit den Heimvorteil zurückerobert. Die Partie nahm in den ersten 30 Minuten einen einseitigen Verlauf. Die Zürcher führten nach Treffern von Streit (2), Kout, Camenzind und Stirnimann mit 5:1, für die enttäuschenden Davoser hatte lediglich Nash getroffen. Im Schlussdrittel kehrten jedoch die Verhältnisse. Die Davoser kamen begünstigt durch eine 5-Minuten-Strafe gegen Zeiter noch einmal auf 4:5 heran, ehe Alston für das Endergebnis sorgte.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Siege für Davos und ZSC — 2024-11-28
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e6f2ff;color:#003366;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     FTS: 0.0147
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 10.8570
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>9c0499d4-505f-475b-9db6-c37425c08d9e
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Tabellenführer HC Davos hat das Spitzenspiel gegen das drittklassierte Lausanne auswärts klar mit 6:2 gewonnen. Entscheidend war ein Davoser Doppelschlag im Mitteldrittel innert 13 Sekunden - und das in Unterzahl. Kessler und Stransky stellten auf 3:1.
#
# Mit den ZSC Lions hat auch der Tabellenzweite seine Partie gewonnen. Beim 4:0 beim EV Zug sorgten Grant (13.), Andrighetto (16.), Kinnunen (32.) und&nbsp; Lehtonen (52.) für die Tore der Zürcher. Malgin glänze als dreifacher Assistgeber. Damit verpasst es Zug, den Druck auf die vorderen Ränge zu erhöhen und verbleibt auf Platz 5.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     HC Davos holt Meistertitel! — 2005-04-07
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e6f2ff;color:#003366;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     FTS: 0.0073
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 10.7735
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>07-04-2005_EISHOCKEY_HC_Davos_holt_Meistertitel
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Der HC Davos hat zum 27. Mal in der Klubgeschichte den Meistertitel gewonnen. Die Bündner gewannen das fünfte Spiel gegen die ZSC Lions mit 3:2 nach Verlängerung und siegten in der Serie damit deutlich mit 4:1. Den entscheidenden Treffer erzielte Schwerarbeiter Josef Marha nach 8'24" in der Overtime. In der regulären Spielzeit hatten zuvor Björn Christen und Michel Riesen sowie Sven Helfenstein und Jan Alston getroffen. Die Davoser hätten das Spiel bereits früher entscheiden können, vergaben jedoch eine Vielzahl Chancen.
#             </p>
#         </div>

# %%
retrieval_query("Was US-President Trump at the WEF in Davos?")
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     WEF 2018: Trump in Davos gelandet — 2018-01-25
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8306
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 10.9133
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>1c47525c-5428-4b54-adf2-3fc5aec2fc6b
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>US-Präsident Donald Trump ist in der Schweiz angekommen. Die Air Force One landete am Donnerstagmorgen um 10.20 Uhr auf dem Flughafen Zürich. &nbsp;
#
# Trump wird in Davos am Weltwirtschaftsforum WEF mit der britischen Premierministerin Theresa May, Israels Ministerpräsident Benjamin Netanjahu zusammentreffen. In beiden Treffen soll es um internationale Krisen, etwa in Nordkorea und im Iran, sowie um den Kampf
# gegen den internationalen Terrorismus
# gehen.
#
# Erst am Freitag soll der US-Präsident am WEF öffentlich auftreten und die Schlussrede halten. Zuvor wird er gemäss Programm auch mit Bundespräsident Alain Berset ein Gespräch führen.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Trump ist für fairen Handel — 2018-01-26
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8123
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 10.7443
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>7e22e31e-1b4a-4ded-9a93-a6ba42dd2d7f
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>US-Präsident Trump hat sich bei seiner Rede am WEF in Davos für gegenseitig fairen Handel ausgesprochen. In seiner 20-minütigen Rede sagte Trump, seine Regierung werde die USA immer an erster Stelle setzen. «America first» bedeute aber nicht, Amerika alleine.
#
# Trump bot den beteiligten Ländern auch neue Gespräche über das transpazifische Handelsabkommen TPP an. Die USA seien offen für Gespräche, entweder individuell oder innerhalb der Gruppe.
#
# Trump lobte die Steuerreform seiner Regierung und erklärte, die Welt erlebe den Wiederaufstieg eines starken und wohlhabenden Amerikas. Nie habe es einen besseren Zeitpunkt gegeben, um dort zu arbeiten oder investieren.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Donald Trump will nach Davos kommen — 2018-01-22
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8293
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 10.6499
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>36b256e9-69c0-4ab8-9945-229235e6588f
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>US-Präsident Donald Trump reist ans Weltwirtschaftsforum WEF in Davos. Das bestätigte das Weisse Haus, nachdem Republikaner und Demokraten im Senat einen Kompromiss im Budgetstreit gefunden hatten.
#
# Der US-Delegation am WEF gehören neben Trump unter anderem Aussenminister Rex Tillerson, Finanzminister Steven Mnuchin, Wirtschaftsminister Wilbur Ross und Präsidentenberater Jared Kushner an.
#
# UNO-Generalsekretär António Guterres hingegen wird diesmal, anders als letztes Jahr, nicht nach Davos reisen. Grund seien «Terminprobleme», sagte sein Sprecher in New York.
#             </p>
#         </div>

# %%
retrieval_query("Wann wurde in Trimmis eine Bank überfallen?")
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Zwei Männer überfallen Bankfiliale — 2013-02-26
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8734
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 4.2421
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>228f3578-e5c6-4e0d-8a3c-6a71e4aeb136
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>In Trimmis im Kanton Graubünden haben am Dienstagabend zwei maskierte Männer die Filiale der Raiffeisenbank überfallen. Nach Angaben der Polizei bedrohten sie die Bankangestellten mit vorgehaltenen Waffen, steckten Geld in eine Umhängetasche und flohen. Welche Summe die Täter erbeuteten, ist noch unklar.
#             </p>
#         </div>

# %%
retrieval_query("Does Migros sell Feldschlösschen?")
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Kein Feldschlösschen bei Migros — 2026-01-06
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8595
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 10.7996
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>14bc6559-c121-4872-9390-60e6afbb9add
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Die Brauerei Feldschlösschen beliefert die Migros und ihre Tochterfirmen, wie Migrolino und Denner, momentan nicht.
#
# Hintergrund ist ein Preiskampf der beiden Unternehmen, Feldschlösschen hat einen entsprechenden Bericht des Blick gegenüber der Nachrichtenagentur AWP bestätigt. Betroffen sind nicht nur Biere, sondern auch andere Getränke die der Bierbrauer in der Schweiz herstellt oder vertreibt, etwa die Marken Rhäzünser, Guinness oder Pepsi.
#
# Feldschlösschen sagt dazu, man sei zuversichtlich, dass die Produkte bald wieder bei den Migros-Unternehmen erhältlich seien.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Feldschlösschen beliefert Migros wieder — 2026-01-10
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8460
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 10.2614
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>d56a2a55-60bf-49a5-9258-be80e37342a5
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Die Migros-Gruppe und Feldschlösschen haben sich im Preisstreit geeinigt. In den zur Migros gehörenden Denner-Filialen und bei Migrolino wird wieder das vollständige Sortiment von Feldschlösschen-Bieren zu den üblichen Preisen angeboten.
#
# Die Denner-Medienstelle bestätigte am Samstagabend auf Anfrage eine entsprechende Blick-Meldung. Die Einigung sei am Freitagabend zustande gekommen.
#
# Am vergangenen Dienstag war der Preisstreit zwischen der Migros-Gruppe und der Bierbrauerei bekannt geworden. Feldschlösschen hatte mitgeteilt, der Konzern habe sich entschieden, die Migros-Gruppe vorübergehend nicht mit&nbsp;Produkten zu beliefern.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Mineralwasser in diesen Tagen gefragt — 2003-06-13
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8037
#                 </span>
#
#                 <span style="background-color:#f3e8ff;color:#4b1b7a;padding:2px 6px;border-radius:4px;">
#                     Cross: 4.3185
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>13-06-2003_Mineralwasser_in_diesen_Tagen_gefragt
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Mit den Temperaturen steigt auch die Nachfrage nach Mineralwasser. Der Absatz der Feldschlösschen Getränke AG lag in den ersten Juni-Tagen um 50 % über dem Wert des Vorjahres. Auch bei Coop hat sich der Mineralwasserverkauf in der letzten Woche verdoppelt. Henniez-Chef Nicolas Rouge schwärmt: "Der Absatz läuft derzeit auf Hochtouren. Wir arbeiten von morgens 6 Uhr bis spätabends." Auch bei Migros läuft die Umsatzentwicklung nach eigenen Angaben seit Anfang Jahr sehr positiv. Nach wie vor weiter im Zunehmen ist dabei die Vorliebe für "stille Wasser" (ohne Kohlensäure).
#             </p>
#         </div>

# %% [markdown]
# # Comments on full text (FTS) vs semantic similarity (vector) search
# ## Postgres Full text search
# - based on [tsvector](https://www.postgresql.org/docs/current/datatype-textsearch.html)
# - lexical (token-based) information retrieval system
# - efficient normalization and indexing and retrieval
# - restricted to same language (german)
# - **Which documents contain these words, and how important are they?**
# ## Semantic similarity search
# - Based on embedding models ([multilingual-e5-large](https://arxiv.org/pdf/2402.05672))
# - allows cross-language queries
# - **Which documents are semantically similar in meaning?**
#
# Short queries (e.g. single keywords) have a better recall using full text search, whereas long queries (e.g. questions) work much better with semantic similarity search
#
# *Conclusion*: Do both, deduplicate results and feed them to the reranker

# %%
# Example: short query with FTS with a very specific keyword (name of small village) ==> matching result
r = dr.fts_search("Mastrils", k=2)
display_search_results(r)
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Liste der 14 Grosswasserkraftwerke — 2012-04-17
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e6f2ff;color:#003366;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     FTS: 0.1000
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>17-04-2012_Liste_der_14_Grosswasserkraftwerke
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Das Bundesamt für Energie schlägt laut einer der Sendung "10vor10" vorliegenden Liste 14 Standorte für neue Grosswasserkraftwerke vor. Die meisten liegen in den Kantonen Graubünden und Wallis. Hier die vollständige List der vorgeschlagenen Standorte: Barrage de Conflan/GE, RothenbrunnenReichenau/GR, Ems-Mastrils/GR/SG, Ilanz-Reichenau/GR, Küblis-Landquart/GR, Litzirüti-Pradapunt/GR, Martina-Prutz/GR, Naz-Bergün/GR, Lugnez/GR, Alpenrhein/SG/FL, GletschOberwald/VS, Massongex-Bex-Rhone/VS, Oberaletsch-Gebidem/VS, Randa Mattsand/VS.
#             </p>
#         </div>

# %%
# Example: short query with vector search with a very specific keyword (name of small village) ==> nonsense results
r = dr.vector_similarity_search("Mastrils", k=2)
display_search_results(r)
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     . — 2013-09-29
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8120
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>4777ba2d-a315-49f5-abc6-1de276d60533
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     GCK L. -Biel DO 20.00 Uhr — 2007-01-18
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.8013
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>18-01-2007_GCK_L_Biel_DO_20_00_Uhr
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>KEK                                     SR: Stricker; Kaderli, Müller
#             </p>
#         </div>

# %%
# Example: long, semantic query in other language with FTS ==> no matches
r = dr.fts_search("When did the Rolling Stones publish a song? ", k=2)
display_search_results(r)

# %%
# Example: long, semantic query in other language with vector ==> relevant matches
r = dr.vector_similarity_search("When did the Rolling Stones publish a song? ", k=2)
display_search_results(r)
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Stones veröffentlichen Aufnahme — 2020-07-22
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.7816
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>cc09f555-1e6d-4317-970b-ded7221f6e30
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Drei Monate nach dem Single-Comeback mit «Living In A Ghost Town» überraschen die Rolling Stones erneut ihre Fans, diesmal mit einer 46 Jahre alten Aufnahme.
#
# Das offiziell auf YouTube erschienene Stück «Scarlet» stammt aus dem Oktober 1974, eingespielt wurde es mit Jimmy Page von der britischen Rockband Led Zeppelin an der Gitarre neben Keith Richards.
#
# Wie das Musiklabel Universal am Mittwoch weiter mitteilte, wurde der Song «niemals zuvor veröffentlicht». Die Veröffentlichung kündigt eine Neuauflage des Stones-Albums «Goats Head Soup» von 1973 an, das am 4. September herauskommen soll.
#             </p>
#         </div>
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Rolling Stones heizen Album-Gerüchte an — 2023-08-23
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 0.7815
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>4a23bc5d-ffa1-4214-a08b-be69d83a0a94
#             </p>
#
#             <p style="font-size:0.8rem;">
#                 <strong>Content</strong><br>Bringen die Rolling Stones bald ein neues Album heraus?
#
# Eine Anzeige für das fiktive Glasreparaturunternehmen «Hackney Diamonds» in der Londoner Lokalzeitung «Hackney Gazette» befeuert Gerüchte über ein 31. Studioalbum der britischen Rockband um Frontman Mick Jagger (80). Die Anzeige spielt auf die Stones-Hits «Satisfaction», «Gimme Shelter» und «Shattered» an: «Unser freundliches Team verspricht Ihnen Satisfaction. Wenn Sie Gimme Shelter sagen, werden wir Ihre shattered Fenster reparieren.»
#
# Die Stones hatten immer wieder vage Andeutungen über ein neues Album gemacht.
#             </p>
#         </div>
