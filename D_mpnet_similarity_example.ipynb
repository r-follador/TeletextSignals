# %% [markdown]
# # MPNet Similarity Lookup
#
# Retrieve the closest documents to a known `teletext_id` using the `emb_teletext_full.embedding_mpnet` vector.

# %%
from modules.mpnet_similarity import mpnet_nearest_docs_by_teletext_id
from modules.notebook_helpers import display_search_results

example_id = "89128a37-880e-4793-aa34-967a31cdf97c"
results = mpnet_nearest_docs_by_teletext_id(example_id, k=10)
display_search_results(results, max_content_chars=800)
# Out:
#         <div style="border:1px solid #ddd;border-radius:6px;padding:12px;margin-bottom:12px;background-color:#fafafa;font-size:0.85rem;">
#             <div style="display:flex;justify-content:space-between;align-items:baseline;">
#                 <h3 style="margin:0;font-family:ui-monospace,SFMono-Regular,Menlo,Consolas,'Liberation Mono',monospace;font-size:0.95rem;font-weight:500;">
#                     Neuer Präsident vereidigt — 2019-12-10
#                 </h3>
#                 <div style="font-size:0.8rem;">
#                 <span style="background-color:#e8f8f0;color:#0a4d2f;padding:2px 6px;border-radius:4px;margin-right:6px;">
#                     Vector: 1.0000
#                 </span>
#                 </div>
#             </div>
#
#             <p style="margin-top:8px;font-size:0.8rem;">
#                 <strong>Teletext ID</strong><br>89128a37-880e-4793-aa34-967a31cdf97c
#             </p>
#
#             <p style="font-size:0.8rem;">
# ...
