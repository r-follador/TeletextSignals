# %% [markdown]
# # Agentic RAG
# Slower but more flexibel.
# - LLM Agent queries the documents (i.e. rewrites queries as it seems fit)
# - Can query multiple times if necessary
# - Needs more LLM calls

# %%
from modules.langchain_agentic_rag import make_teletext_agentic_rag
from modules.notebook_helpers import display_cited_sources, display_answer

rag = make_teletext_agentic_rag(
    model="qwen2.5:7b-instruct",
    base_url="http://localhost:11434",
    k=40,
    top_k=10,
    debug=True,
)
def query(question):
    answer, sources = rag.ask_with_sources(question)
    display_answer(answer)
    display_cited_sources(answer, sources)
# Out:
# /home/rainer/IdeaProjects/TeletextSignals/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
query("Welche Staatsoberhäupter wurden wann am WEF gemeldet?")
# Out:
# [values] {'messages': [HumanMessage(content='Welche Staatsoberhäupter wurden wann am WEF gemeldet?', additional_kwargs={}, response_metadata={}, id='de8e0367-2907-48d5-87db-81ea8c101639')]}
# [updates] {'model': {'messages': [AIMessage(content='linik\n{"name": "teletext_search", "arguments": {"query": "WEF Staatsnobelpreisträger"}}\n</tool_call>', additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b-instruct', 'created_at': '2026-01-06T20:18:58.973164577Z', 'done': True, 'done_reason': 'stop', 'total_duration': 13750033842, 'load_duration': 5323949344, 'prompt_eval_count': 223, 'prompt_eval_duration': 2573340129, 'eval_count': 31, 'eval_duration': 5745327563, 'logprobs': None, 'model_name': 'qwen2.5:7b-instruct', 'model_provider': 'ollama'}, id='lc_run--019b94f6-4164-72f0-a708-2764cbe8376e-0', usage_metadata={'input_tokens': 223, 'output_tokens': 31, 'total_tokens': 254})]}}
# ...

# %%
query("Zeig mir alle rapportierten Gefängnisausbrüche")
# Out:
# [values] {'messages': [HumanMessage(content='Zeig mir alle rapportierten Gefängnisausbrüche', additional_kwargs={}, response_metadata={}, id='7883820b-5a5a-4a2c-99a0-621ea7fa8d35')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:7b-instruct', 'created_at': '2026-01-06T20:19:07.383399196Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8289038132, 'load_duration': 176990923, 'prompt_eval_count': 219, 'prompt_eval_duration': 1527308094, 'eval_count': 35, 'eval_duration': 6470267243, 'logprobs': None, 'model_name': 'qwen2.5:7b-instruct', 'model_provider': 'ollama'}, id='lc_run--019b94f6-7794-7883-88ef-ddbceeb6c6f4-0', tool_calls=[{'name': 'teletext_search', 'args': {'query': 'Gefängnisaustritt Gefängnisausbruch'}, 'id': 'b6659444-2060-4882-8b46-b6b36d963d7a', 'type': 'tool_call'}], usage_metadata={'input_tokens': 219, 'output_tokens': 35, 'total_tokens': 254})]}}
# ...
